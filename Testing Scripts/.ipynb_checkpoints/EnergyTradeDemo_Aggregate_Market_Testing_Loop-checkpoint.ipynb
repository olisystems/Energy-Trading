# %%
# coding: utf-8

import json
import time
import datetime
import requests
import math
import random
import requests
from requests_oauthlib import OAuth1Session
from requests_oauthlib import OAuth1

from web3 import Web3, KeepAliveRPCProvider, IPCProvider, HTTPProvider

# %%
web3 = Web3(HTTPProvider("http://127.0.0.1:8545", request_kwargs={'timeout': 600}))

coinbase = web3.eth.coinbase
web3.eth.defaultBlock = "latest"
transaction = {'from': coinbase}

# %%
# define the adress, ABI (with parsing from str to JSON) and define the contract object
Oliorigin_address = '0xe844d053fcfefb31ce5a169f0efd36bff7f45795'
Oliorigin_abi_str  = '[{"constant":true,"inputs":[{"name":"_account","type":"address"}],"name":"get_oliType","outputs":[{"name":"","type":"uint8"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"name":"_account","type":"address"}],"name":"get_oliCkt","outputs":[{"name":"","type":"uint8"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[],"name":"kill","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":true,"inputs":[{"name":"_account","type":"address"}],"name":"get_oliTrafoid","outputs":[{"name":"","type":"uint32"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"name":"_tid","type":"uint32"}],"name":"get_gsoAddr","outputs":[{"name":"","type":"address"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"name":"_account","type":"address"},{"name":"_index","type":"uint8"}],"name":"get_oliPeakLoad","outputs":[{"name":"","type":"uint16"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[{"name":"oli","type":"address"},{"name":"lat","type":"uint32"},{"name":"long","type":"uint32"},{"name":"trafo","type":"uint32"},{"name":"ckt","type":"uint8"},{"name":"typex","type":"uint8"},{"name":"pload","type":"uint16[]"}],"name":"addOli","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"anonymous":false,"inputs":[{"indexed":false,"name":"paymentAddress","type":"address"},{"indexed":false,"name":"latOfLocation","type":"uint32"},{"indexed":false,"name":"longOfLocation","type":"uint32"}],"name":"newAddedOli","type":"event"}]'
Oliorigin_abi      = json.loads(Oliorigin_abi_str)
Oliorigin_contract = web3.eth.contract(abi=Oliorigin_abi,address=Oliorigin_address)

# %%
# define the adress, ABI (with parsing from str to JSON) and define the contract object
Olicoin_address = '0x091b602160636a0634d32a6fa886ce600d8dbb16'
Olicoin_abi_str  = '[{"constant":false,"inputs":[],"name":"kill","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":true,"inputs":[{"name":"caddress","type":"address"}],"name":"get_coinBalance","outputs":[{"name":"","type":"int32"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[{"name":"_contract","type":"address"},{"name":"_tf","type":"bool"}],"name":"set_ContractAddress","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"_account","type":"address"},{"name":"_change","type":"int32"}],"name":"set_OliCoinBalance","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"_to","type":"address"},{"name":"_amount","type":"uint16"}],"name":"transfer","outputs":[{"name":"success","type":"bool"}],"payable":false,"stateMutability":"nonpayable","type":"function"},{"anonymous":false,"inputs":[{"indexed":true,"name":"_from","type":"address"},{"indexed":true,"name":"_to","type":"address"},{"indexed":false,"name":"_value","type":"uint16"}],"name":"Transfer","type":"event"}]'
Olicoin_abi      = json.loads(Olicoin_abi_str)
Olicoin_contract = web3.eth.contract(abi=Olicoin_abi,address=Olicoin_address)

# %%
# define the adress, ABI (with parsing from str to JSON) and define the contract object
Olibilateral_address = '0xbf9523daa21dd82a7b898a8b14d870d477ddd2bf'
Olibilateral_abi_str  = '[{"constant":false,"inputs":[{"name":"addr","type":"address"}],"name":"setOliOrigin","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"_stock","type":"address"},{"name":"_rate","type":"uint8"}],"name":"stockBidding","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":true,"inputs":[{"name":"_stock","type":"address"}],"name":"get_stockAmount","outputs":[{"name":"","type":"uint16"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[],"name":"kill","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"_amount","type":"uint16"},{"name":"_rate","type":"uint8"},{"name":"_period","type":"uint32"},{"name":"_btime","type":"uint32"}],"name":"regStock","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":true,"inputs":[{"name":"_stock","type":"address"}],"name":"get_stockBidder","outputs":[{"name":"","type":"address"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"name":"_stock","type":"address"}],"name":"get_stockRate","outputs":[{"name":"","type":"uint8"}],"payable":false,"stateMutability":"view","type":"function"},{"anonymous":false,"inputs":[{"indexed":false,"name":"saccount","type":"address"},{"indexed":false,"name":"samount","type":"uint16"},{"indexed":false,"name":"smrate","type":"uint8"},{"indexed":false,"name":"speriod","type":"uint32"},{"indexed":false,"name":"sbiddingTime","type":"uint32"}],"name":"NewStock","type":"event"},{"anonymous":false,"inputs":[{"indexed":false,"name":"baccount","type":"address"},{"indexed":false,"name":"bmrate","type":"uint8"}],"name":"NewStockBid","type":"event"}]'
Olibilateral_abi      = json.loads(Olibilateral_abi_str)
Olibilateral_contract = web3.eth.contract(abi=Olibilateral_abi,address=Olibilateral_address)

# %%
# define the adress, ABI (with parsing from str to JSON) and define the contract object
Olidaughter_address = '0xaca7ef8d886e46cc1153f61c6b60e6359c1d09a9'
Olidaughter_abi_str  = '[{"constant":false,"inputs":[{"name":"addr","type":"address"}],"name":"setOliOrigin","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"_amount","type":"uint16"},{"name":"_rate","type":"uint8"}],"name":"bid","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"addr","type":"address"}],"name":"setBilateralTrading","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"addr","type":"address"}],"name":"setOliCoin","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"addr","type":"address"}],"name":"setDynamicGridFee","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[],"name":"kill","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[],"name":"resett","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":true,"inputs":[],"name":"get_producer","outputs":[{"name":"","type":"address[]"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"name":"_rate","type":"uint8"}],"name":"get_sRate","outputs":[{"name":"","type":"uint16"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[],"name":"get_consumer","outputs":[{"name":"","type":"address[]"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"name":"_rate","type":"uint8"}],"name":"get_dRate","outputs":[{"name":"","type":"uint16"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[],"name":"maxRate","outputs":[{"name":"","type":"uint8"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[],"name":"breakEven","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"inputs":[],"payable":false,"stateMutability":"nonpayable","type":"constructor"},{"anonymous":false,"inputs":[{"indexed":true,"name":"gaddr","type":"address"},{"indexed":false,"name":"grate","type":"uint8"},{"indexed":false,"name":"gamount","type":"uint16"}],"name":"NewGenBid","type":"event"},{"anonymous":false,"inputs":[{"indexed":true,"name":"caddr","type":"address"},{"indexed":false,"name":"crate","type":"uint8"},{"indexed":false,"name":"camount","type":"uint16"}],"name":"NewConBid","type":"event"},{"anonymous":false,"inputs":[{"indexed":false,"name":"cbid","type":"uint8"}],"name":"NewMcp","type":"event"}]'
Olidaughter_abi      = json.loads(Olidaughter_abi_str)
Olidaughter_contract = web3.eth.contract(abi=Olidaughter_abi,address=Olidaughter_address)

# %%
# define the adress, ABI (with parsing from str to JSON) and define the contract object
DynamicGridFee_address = '0xd1131bf9c4ec846878110611817924da73fc534e'
DynamicGridFee_abi_str  = '[{"constant":true,"inputs":[{"name":"_tid","type":"uint32"},{"name":"_index","type":"uint8"}],"name":"get_gridFee","outputs":[{"name":"","type":"uint8"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[{"name":"_addr","type":"address"},{"name":"_amount","type":"uint16"}],"name":"set_trafocamount","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"addr","type":"address"}],"name":"setOliOrigin","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"_addr","type":"address"},{"name":"_amount","type":"uint16"}],"name":"set_cktcamount","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[],"name":"kill","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"_tid","type":"uint32"}],"name":"set_tgridFee","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":true,"inputs":[{"name":"_tid","type":"uint32"},{"name":"_index","type":"uint8"}],"name":"get_cktAmount","outputs":[{"name":"","type":"int16"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":true,"inputs":[{"name":"_addr","type":"address"}],"name":"get_tGFee","outputs":[{"name":"","type":"uint8"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[{"name":"_address","type":"address"},{"name":"_fee","type":"uint8[]"}],"name":"set_minmaxgfee","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"_addr","type":"address"},{"name":"_amount","type":"uint16"}],"name":"set_traforamount","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":true,"inputs":[{"name":"_addr","type":"address"}],"name":"get_dGFee","outputs":[{"name":"","type":"uint8"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[{"name":"_tid","type":"uint32"}],"name":"set_dgridFee","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":false,"inputs":[{"name":"_addr","type":"address"},{"name":"_amount","type":"uint64"}],"name":"set_cktramount","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":true,"inputs":[{"name":"_addr","type":"address"}],"name":"get_trafoAmount","outputs":[{"name":"","type":"int16"}],"payable":false,"stateMutability":"view","type":"function"}]'
DynamicGridFee_abi      = json.loads(DynamicGridFee_abi_str)
DynamicGridFee_contract = web3.eth.contract(abi=DynamicGridFee_abi,address=DynamicGridFee_address)

# %%
account_0=web3.eth.accounts[0]
account_1=web3.eth.accounts[1]
account_2=web3.eth.accounts[2]
account_3=web3.eth.accounts[3]
account_4=web3.eth.accounts[4]
account_5=web3.eth.accounts[5]
account_6=web3.eth.accounts[6]
account_7=web3.eth.accounts[7]
account_8=web3.eth.accounts[8]
account_9=web3.eth.accounts[9]
account_10=web3.eth.accounts[10]
account_11=web3.eth.accounts[11]
account_12=web3.eth.accounts[12]
account_13=web3.eth.accounts[13]
account_14=web3.eth.accounts[14]
account_15=web3.eth.accounts[15]
account_16=web3.eth.accounts[16]
account_17=web3.eth.accounts[17]
account_18=web3.eth.accounts[18]
account_19=web3.eth.accounts[19]
account_20=web3.eth.accounts[20]
account_21=web3.eth.accounts[21]
account_22=web3.eth.accounts[22]

# %%
#OLIDaughterAuction1 bid
run = 1
while run == 1:
    web3.personal.unlockAccount(account_1, 'hassan')
    Olidaughter_contract.transact({'from': account_1}).bid(int(rest_power()/10000), 2)

    web3.personal.unlockAccount(account_2, 'hassan')
    Olidaughter_contract.transact({'from': account_2}).bid(random.randint(100,105), 10)

    web3.personal.unlockAccount(account_3, 'hassan')
    Olidaughter_contract.transact({'from': account_3}).bid(random.randint(50,55), 13)

    web3.personal.unlockAccount(account_4, 'hassan')
    Olidaughter_contract.transact({'from': account_4}).bid(random.randint(200,205), 14)

    web3.personal.unlockAccount(account_5, 'hassan')
    Olidaughter_contract.transact({'from': account_5}).bid(random.randint(155,160), 15)

    #    time.sleep(15)

    web3.personal.unlockAccount(account_6, 'hassan')
    Olidaughter_contract.transact({'from': account_6}).bid(random.randint(100,105), 9)

    web3.personal.unlockAccount(account_7, 'hassan')
    Olidaughter_contract.transact({'from': account_7}).bid(random.randint(150,155), 10)

    web3.personal.unlockAccount(account_8, 'hassan')
    Olidaughter_contract.transact({'from': account_8}).bid(random.randint(200,255), 12)

    web3.personal.unlockAccount(account_9, 'hassan')
    Olidaughter_contract.transact({'from': account_9}).bid(random.randint(100,105), 13)

    web3.personal.unlockAccount(account_10, 'hassan')
    Olidaughter_contract.transact({'from': account_10}).bid(random.randint(300,305), 14)

    time.sleep(30)
    
    #MCP
    web3.personal.unlockAccount(account_9, 'hassan')
    Olidaughter_contract.transact({'from': account_9}).breakEven()    
    time.sleep(30)
    web3.personal.unlockAccount(account_10, 'hassan')
    Olidaughter_contract.transact({'from': account_10}).resett()    
    time.sleep(30)
# Out:
# 200
# jq045evf4bjpvsti3847a4aaou
# {b'oauth_token': [b'f204d49449c14785afb1276fc1502c5e'], b'oauth_token_secret': [b'7f4f14c9bf1e45349bad5c0812870874'], b'oauth_callback_confirmed': [b'true']}
# f204d49449c14785afb1276fc1502c5e
# 7f4f14c9bf1e45349bad5c0812870874
# oauth_verifier=3ea08864eb234d19be2b8850ea066c4f
# 3ea08864eb234d19be2b8850ea066c4f
# hhhhh
# b'oauth_token=19f92db3cfe54c429e4a326803afa4ce&oauth_token_secret=c8859403f87948c392562f44a8f326f4'
# 19f92db3cfe54c429e4a326803afa4ce
# c8859403f87948c392562f44a8f326f4
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521646322000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521646322000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521646323000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521646385807}]'
# b'{"time":1521646385807,"values":{"power":3737590,"power3":1250350,"energyOut":34624264000,"power1":1243560,"energy":11673354487000,"power2":1243680}}'
# 200
# 200
# itc3q5ibr8np01cob9eiom4ge1
# {b'oauth_token': [b'5b4dea39f37c44638c4a8c578c401284'], b'oauth_token_secret': [b'b6932222ebe54ff0aead9bb3d3a927fb'], b'oauth_callback_confirmed': [b'true']}
# 5b4dea39f37c44638c4a8c578c401284
# b6932222ebe54ff0aead9bb3d3a927fb
# oauth_verifier=56fac9e0456441e88485d9789a50bc91
# 56fac9e0456441e88485d9789a50bc91
# hhhhh
# b'oauth_token=95bb83025f9541519f31ed64255d76cc&oauth_token_secret=fdf3d331e78c43ae9844eb35cd33dbbb'
# 95bb83025f9541519f31ed64255d76cc
# fdf3d331e78c43ae9844eb35cd33dbbb
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521646444000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521646442000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521646443000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521646489807}]'
# b'{"time":1521646489807,"values":{"power":3579130,"power3":1191630,"energyOut":34624264000,"power1":1197920,"energy":11674411604000,"power2":1189580}}'
# 200
# 200
# dpm5hv4g1n5t37oc15084khh3g
# {b'oauth_token': [b'a587129f29db4abd984760dd67ac1835'], b'oauth_token_secret': [b'b327ce5697d145c499cece1f940c2c41'], b'oauth_callback_confirmed': [b'true']}
# a587129f29db4abd984760dd67ac1835
# b327ce5697d145c499cece1f940c2c41
# oauth_verifier=0e6578fc54cd4858bd28fb28df1bf073
# 0e6578fc54cd4858bd28fb28df1bf073
# hhhhh
# b'oauth_token=a1976f8379964e05a48e44408c5435fb&oauth_token_secret=708802b1705e4b6aaa2ed3ebeabc44a5'
# a1976f8379964e05a48e44408c5435fb
# 708802b1705e4b6aaa2ed3ebeabc44a5
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521646563000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521646563000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521646563000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521646593750}]'
# b'{"time":1521646593750,"values":{"power":3419750,"power3":1143010,"energyOut":34624264000,"power1":1140980,"energy":11675424665000,"power2":1135760}}'
# 200
# 200
# 2hkfrgpb42bua9pm9p54lofqkd
# {b'oauth_token': [b'c51637df73c84d5782051c8f433ba9af'], b'oauth_token_secret': [b'7e25636aa82149f38d461c09634bd7a0'], b'oauth_callback_confirmed': [b'true']}
# c51637df73c84d5782051c8f433ba9af
# 7e25636aa82149f38d461c09634bd7a0
# oauth_verifier=c1dfaead3a7d42189886d7e829d603a7
# c1dfaead3a7d42189886d7e829d603a7
# hhhhh
# b'oauth_token=decbf77b95cb4388b681411897f2181f&oauth_token_secret=afebf903512c47eda152405ecee9e7d3'
# decbf77b95cb4388b681411897f2181f
# afebf903512c47eda152405ecee9e7d3
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521646622000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521646622000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521646623000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521646695750}]'
# b'{"time":1521646695750,"values":{"power":3270890,"power3":1090430,"energyOut":34624264000,"power1":1093040,"energy":11676372196000,"power2":1087420}}'
# 200
# 200
# 9k405peiru5p9cp5ifl8m0kk15
# {b'oauth_token': [b'26e2e5b5d4144d79b77eb49dbdfb6ff9'], b'oauth_token_secret': [b'3a1e782d46604a27afcb3d25323abc4a'], b'oauth_callback_confirmed': [b'true']}
# 26e2e5b5d4144d79b77eb49dbdfb6ff9
# 3a1e782d46604a27afcb3d25323abc4a
# oauth_verifier=98b79a56af59411596e9d967c186b350
# 98b79a56af59411596e9d967c186b350
# hhhhh
# b'oauth_token=80d41e1a49fb46c78d288c101313493f&oauth_token_secret=8dba4a91d50440b8bcb2d834a12db118'
# 80d41e1a49fb46c78d288c101313493f
# 8dba4a91d50440b8bcb2d834a12db118
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521646743000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521646743000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521646743000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521646797751}]'
# b'{"time":1521646797751,"values":{"power":3127090,"power3":1043370,"energyOut":34624264000,"power1":1045970,"energy":11677277076000,"power2":1037750}}'
# 200
# 200
# v51f0l039jov9ujkkd9gs0tlro
# {b'oauth_token': [b'5713ae54c58749bdbb8a18552a5684b8'], b'oauth_token_secret': [b'00df69514b2b4456bb2d6c38f9b1c162'], b'oauth_callback_confirmed': [b'true']}
# 5713ae54c58749bdbb8a18552a5684b8
# 00df69514b2b4456bb2d6c38f9b1c162
# oauth_verifier=60681c81243441c696ec3cc35ee00fdb
# 60681c81243441c696ec3cc35ee00fdb
# hhhhh
# b'oauth_token=cd0c489623834a5fb66b2f9451ab96ff&oauth_token_secret=dfd7e498274c44f9aed6b343b621ed24'
# cd0c489623834a5fb66b2f9451ab96ff
# dfd7e498274c44f9aed6b343b621ed24
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521646863000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521646863000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521646862000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521646899751}]'
# b'{"time":1521646899751,"values":{"power":2966590,"power3":992390,"energyOut":34624264000,"power1":987680,"energy":11678141200000,"power2":986520}}'
# 200
# 200
# 9ftidsfupr0pns787204sjvqkb
# {b'oauth_token': [b'58ae173989dd46feb2745aff4756288d'], b'oauth_token_secret': [b'42554886af284e7384482bd7ba02b49d'], b'oauth_callback_confirmed': [b'true']}
# 58ae173989dd46feb2745aff4756288d
# 42554886af284e7384482bd7ba02b49d
# oauth_verifier=781e63935f524447ac172974889f3927
# 781e63935f524447ac172974889f3927
# hhhhh
# b'oauth_token=ac6911fb7c4a4b5eb37494a2745a046b&oauth_token_secret=bfa20d0b6b5744f69ae4ca9b8e11ffa8'
# ac6911fb7c4a4b5eb37494a2745a046b
# bfa20d0b6b5744f69ae4ca9b8e11ffa8
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521646983000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521646983000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521646984000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521647003751}]'
# b'{"time":1521647003751,"values":{"power":2831250,"power3":944990,"energyOut":34624264000,"power1":945420,"energy":11678979677000,"power2":940840}}'
# 200
# 200
# r51ub2espq966v32h12h9pp4rr
# {b'oauth_token': [b'4626b330d2834d0c91bfd9a8705b54c3'], b'oauth_token_secret': [b'3148bc537bdc4c25b54a0bab8e6ad0f6'], b'oauth_callback_confirmed': [b'true']}
# 4626b330d2834d0c91bfd9a8705b54c3
# 3148bc537bdc4c25b54a0bab8e6ad0f6
# oauth_verifier=5d7d8db1d6d64d56a8a846c75db9db55
# 5d7d8db1d6d64d56a8a846c75db9db55
# hhhhh
# b'oauth_token=4318e1b2ce70490688fadf423747b49d&oauth_token_secret=61f945574d3c421883f9b4d59cf251b0'
# 4318e1b2ce70490688fadf423747b49d
# 61f945574d3c421883f9b4d59cf251b0
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521647043000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521647042000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521647043000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521647105752}]'
# b'{"time":1521647105752,"values":{"power":2699470,"power3":901000,"energyOut":34624264000,"power1":900180,"energy":11679763789000,"power2":898290}}'
# 200
# 200
# t8gcd15pj167s9rlaibbm7hvld
# {b'oauth_token': [b'9f99dca0de3345c1bdd1a2ffbdd01ede'], b'oauth_token_secret': [b'6bf6e5415cba43c3afaf0a1eb2675119'], b'oauth_callback_confirmed': [b'true']}
# 9f99dca0de3345c1bdd1a2ffbdd01ede
# 6bf6e5415cba43c3afaf0a1eb2675119
# oauth_verifier=68d40180c66d46e3b2be4fd4f3aae90d
# 68d40180c66d46e3b2be4fd4f3aae90d
# hhhhh
# b'oauth_token=9c538060d5c44fcbbc38bc61ab87db32&oauth_token_secret=1838d34b51ad475993770524acaf17cd'
# 9c538060d5c44fcbbc38bc61ab87db32
# 1838d34b51ad475993770524acaf17cd
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521647163000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521647163000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521647163000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521647207752}]'
# b'{"time":1521647207752,"values":{"power":2569310,"power3":858000,"energyOut":34624264000,"power1":857980,"energy":11680510463000,"power2":853330}}'
# 200
# 200
# jgmg8dckhm25jrrkk3batud2vc
# {b'oauth_token': [b'49caf17b2c044e9e86e06b2f3d14b883'], b'oauth_token_secret': [b'd7b0deec71804c5bb0e6d0d0277633d3'], b'oauth_callback_confirmed': [b'true']}
# 49caf17b2c044e9e86e06b2f3d14b883
# d7b0deec71804c5bb0e6d0d0277633d3
# oauth_verifier=fffe7a94025e43c7b6fb48143498929f
# fffe7a94025e43c7b6fb48143498929f
# hhhhh
# b'oauth_token=e8a6310779cd4c2ca6423a0afcbd5b1a&oauth_token_secret=e52bf8e4c5284125ac124f67321e91bd'
# e8a6310779cd4c2ca6423a0afcbd5b1a
# e52bf8e4c5284125ac124f67321e91bd
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521647283000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521647283000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521647282000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521647309752}]'
# b'{"time":1521647309752,"values":{"power":2437200,"power3":814310,"energyOut":34624264000,"power1":811130,"energy":11681218586000,"power2":811760}}'
# 200
# 200
# aimdmmjfbnmndibml9emr5mp1m
# {b'oauth_token': [b'b33c4ad8024d4a22b77cbdc24df3bac3'], b'oauth_token_secret': [b'4b774838a047493ea87fa6e9ad133a4e'], b'oauth_callback_confirmed': [b'true']}
# b33c4ad8024d4a22b77cbdc24df3bac3
# 4b774838a047493ea87fa6e9ad133a4e
# oauth_verifier=bbd1428e60804461b2d71b9bcd6bf7f1
# bbd1428e60804461b2d71b9bcd6bf7f1
# hhhhh
# b'oauth_token=a34c0a2bfcbe46788fed1fa0ed2208c0&oauth_token_secret=2a1ca76a30804cd88577bc95d1460044'
# a34c0a2bfcbe46788fed1fa0ed2208c0
# 2a1ca76a30804cd88577bc95d1460044
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521647344000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521647344000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521647343000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521647411753}]'
# b'{"time":1521647411753,"values":{"power":2299730,"power3":769430,"energyOut":34624264000,"power1":766600,"energy":11681889648000,"power2":763700}}'
# 200
# 200
# ah36h7ke4hipp7hnlsp6gc7rgt
# {b'oauth_token': [b'94c98dd577e14ee7abe2155690dd9608'], b'oauth_token_secret': [b'd79023c58a324774867832def4e133ac'], b'oauth_callback_confirmed': [b'true']}
# 94c98dd577e14ee7abe2155690dd9608
# d79023c58a324774867832def4e133ac
# oauth_verifier=bf89d264fa0044d1aa90657a3ad5f5df
# bf89d264fa0044d1aa90657a3ad5f5df
# hhhhh
# b'oauth_token=0230a5f35f9642cfaf2b37cf92ab8c4d&oauth_token_secret=e330deddf3484e598c2b21382ede7e8d'
# 0230a5f35f9642cfaf2b37cf92ab8c4d
# e330deddf3484e598c2b21382ede7e8d
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521647463000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521647463000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521647463000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521647511753}]'
# b'{"time":1521647511753,"values":{"power":2184030,"power3":734540,"energyOut":34624264000,"power1":724150,"energy":11682512179000,"power2":725340}}'
# 200
# 200
# ung5usnkd0abvu6eesvgvigbta
# {b'oauth_token': [b'5956228e9bde4e2ba97a5a53c7adfe65'], b'oauth_token_secret': [b'8ae89e67299d4eb7a2ace95a8b31151a'], b'oauth_callback_confirmed': [b'true']}
# 5956228e9bde4e2ba97a5a53c7adfe65
# 8ae89e67299d4eb7a2ace95a8b31151a
# oauth_verifier=3b08f5b02a904bfea10987306ddc9e97
# 3b08f5b02a904bfea10987306ddc9e97
# hhhhh
# b'oauth_token=a4bdcfdbeb554ddca88be729d7966d81&oauth_token_secret=dfd2a964c7af46088c5019975e021fe3'
# a4bdcfdbeb554ddca88be729d7966d81
# dfd2a964c7af46088c5019975e021fe3
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521647583000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521647583000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521647582000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521647613753}]'
# b'{"time":1521647613753,"values":{"power":2060300,"power3":694300,"energyOut":34624264000,"power1":682180,"energy":11683113289000,"power2":683820}}'
# 200
# 200
# o5jip9u0imf15mnmg42rregi9u
# {b'oauth_token': [b'91e5223d5f8446d48f474401b90c88d0'], b'oauth_token_secret': [b'83753da2cbb340d684f6343ed076ba0b'], b'oauth_callback_confirmed': [b'true']}
# 91e5223d5f8446d48f474401b90c88d0
# 83753da2cbb340d684f6343ed076ba0b
# oauth_verifier=f293e02c3b664f5b97b8536fe2344fbb
# f293e02c3b664f5b97b8536fe2344fbb
# hhhhh
# b'oauth_token=c2bc09f581914a6eb904d1a5ddd1f098&oauth_token_secret=5c527054267a4cec926e109ed8a12ead'
# c2bc09f581914a6eb904d1a5ddd1f098
# 5c527054267a4cec926e109ed8a12ead
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521647643000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521647642000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521647643000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521647715754}]'
# b'{"time":1521647715754,"values":{"power":1872080,"power3":631690,"energyOut":34624264000,"power1":619020,"energy":11683666854000,"power2":621370}}'
# 200
# 200
# 5ddlaq6tjmrjsu5o9iphh953ns
# {b'oauth_token': [b'cb65dc6feb5146768225dcc763cabf68'], b'oauth_token_secret': [b'5185adf868cc428e863709c2fc1a0e9d'], b'oauth_callback_confirmed': [b'true']}
# cb65dc6feb5146768225dcc763cabf68
# 5185adf868cc428e863709c2fc1a0e9d
# oauth_verifier=fa5e8c9a9d884cd8adf4d803931d96f9
# fa5e8c9a9d884cd8adf4d803931d96f9
# hhhhh
# b'oauth_token=bb063aefb1ee4a73adee552c0e3a4b37&oauth_token_secret=311745415fb74fad8a310444bc04d130'
# bb063aefb1ee4a73adee552c0e3a4b37
# 311745415fb74fad8a310444bc04d130
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521647763000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521647763000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521647763000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521647817754}]'
# b'{"time":1521647817754,"values":{"power":1720690,"power3":582590,"energyOut":34624264000,"power1":567550,"energy":11684145676000,"power2":570550}}'
# 200
# 200
# 9dkg2i8jfalu2lkvshu4f07oo9
# {b'oauth_token': [b'cd55a1806ef942bb9f94162b8108ed10'], b'oauth_token_secret': [b'004cf5bd20b14eed93be7cc8ff95c505'], b'oauth_callback_confirmed': [b'true']}
# cd55a1806ef942bb9f94162b8108ed10
# 004cf5bd20b14eed93be7cc8ff95c505
# oauth_verifier=e0b113debd434d30abc4a0dcb72acc48
# e0b113debd434d30abc4a0dcb72acc48
# hhhhh
# b'oauth_token=1f5f8d0ad7d94cbcb7f0274f87a215ec&oauth_token_secret=bc1872568c7f4692b9bdad0bd2123659'
# 1f5f8d0ad7d94cbcb7f0274f87a215ec
# bc1872568c7f4692b9bdad0bd2123659
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521647883000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521647883000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521647882000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521647919754}]'
# b'{"time":1521647919754,"values":{"power":1731460,"power3":587880,"energyOut":34624264000,"power1":573510,"energy":11684643719000,"power2":570070}}'
# 200
# 200
# 5ndjer8n3arh7jc59cfilv8pth
# {b'oauth_token': [b'b27f960a08f04d87acec20a94043db6d'], b'oauth_token_secret': [b'ce1211eba3864b21b2eafc7dce989f83'], b'oauth_callback_confirmed': [b'true']}
# b27f960a08f04d87acec20a94043db6d
# ce1211eba3864b21b2eafc7dce989f83
# oauth_verifier=cd1e8e5cddeb4ec4ac1eae095326b97d
# cd1e8e5cddeb4ec4ac1eae095326b97d
# hhhhh
# b'oauth_token=90fd08a4ed3a44edab4d3cffd3f7f67a&oauth_token_secret=95f90a95c3a349cfb5700f8d8ec53e9d'
# 90fd08a4ed3a44edab4d3cffd3f7f67a
# 95f90a95c3a349cfb5700f8d8ec53e9d
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521647943000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521647944000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521647943000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521648021755}]'
# b'{"time":1521648021755,"values":{"power":1589800,"power3":540240,"energyOut":34624264000,"power1":527260,"energy":11685115931000,"power2":522300}}'
# 200
# 200
# sv5ngd7c4ha3g0k728l0b6kfka
# {b'oauth_token': [b'3b9ae1ba14114b9d8f6199ee4637457f'], b'oauth_token_secret': [b'd0e5492fd4a3416ab08947d9fff2f457'], b'oauth_callback_confirmed': [b'true']}
# 3b9ae1ba14114b9d8f6199ee4637457f
# d0e5492fd4a3416ab08947d9fff2f457
# oauth_verifier=e33de057976f4b3282e9d3e364170705
# e33de057976f4b3282e9d3e364170705
# hhhhh
# b'oauth_token=2f6a7934943440488af4a2bbba056a45&oauth_token_secret=620abaf4a6ee4323912d2ef9516464ad'
# 2f6a7934943440488af4a2bbba056a45
# 620abaf4a6ee4323912d2ef9516464ad
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521648063000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521648063000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521648063000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521648123755}]'
# b'{"time":1521648123755,"values":{"power":1493940,"power3":506680,"energyOut":34624264000,"power1":496700,"energy":11685556967000,"power2":490560}}'
# 200
# 200
# p5fhgbj56p4qheldplv97lumdk
# {b'oauth_token': [b'c30319d31f194982b77935bec0c20a4a'], b'oauth_token_secret': [b'ce46c936d6174006bc4a8685345c193f'], b'oauth_callback_confirmed': [b'true']}
# c30319d31f194982b77935bec0c20a4a
# ce46c936d6174006bc4a8685345c193f
# oauth_verifier=0f6e5a2af11d482e925b3971f46dcbd9
# 0f6e5a2af11d482e925b3971f46dcbd9
# hhhhh
# b'oauth_token=11dce291bd8e4348a47397939f0b0687&oauth_token_secret=72db52d6bbdb457591b7f7a41003a73c'
# 11dce291bd8e4348a47397939f0b0687
# 72db52d6bbdb457591b7f7a41003a73c
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521648183000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521648183000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521648182000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521648225755}]'
# b'{"time":1521648225755,"values":{"power":1450330,"power3":491450,"energyOut":34624264000,"power1":479370,"energy":11685978985000,"power2":479510}}'
# 200
# 200
# 3094d3msj3etr858rvpa41go7k
# {b'oauth_token': [b'b6665b5c4ed04efd9f88000a5acd419d'], b'oauth_token_secret': [b'82fd93a4e8fd40619028f9f8be798a06'], b'oauth_callback_confirmed': [b'true']}
# b6665b5c4ed04efd9f88000a5acd419d
# 82fd93a4e8fd40619028f9f8be798a06
# oauth_verifier=70af0e36d0c5486988638523d6fef2cd
# 70af0e36d0c5486988638523d6fef2cd
# hhhhh
# b'oauth_token=2d496fb93bbe47ff834bd88c356f75a4&oauth_token_secret=241f352e22b04ecdbcf73ecac924fabe'
# 2d496fb93bbe47ff834bd88c356f75a4
# 241f352e22b04ecdbcf73ecac924fabe
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521648304000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521648304000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521648304000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521648325756}]'
# b'{"time":1521648325756,"values":{"power":1347020,"power3":459180,"energyOut":34624264000,"power1":444140,"energy":11686367125000,"power2":443700}}'
# 200
# 200
# digvt7564b8av1is7amgsj41m0
# {b'oauth_token': [b'c798038b3e004759aa0510f25f88ceaf'], b'oauth_token_secret': [b'efb15c52b7f942a4abd4bfd1b9e98112'], b'oauth_callback_confirmed': [b'true']}
# c798038b3e004759aa0510f25f88ceaf
# efb15c52b7f942a4abd4bfd1b9e98112
# oauth_verifier=e657aa2af36b443da6415224bd10ce0b
# e657aa2af36b443da6415224bd10ce0b
# hhhhh
# b'oauth_token=5ff6592794d64bc29a386b9fce450159&oauth_token_secret=824c539f42aa4371859547ff7ff4c211'
# 5ff6592794d64bc29a386b9fce450159
# 824c539f42aa4371859547ff7ff4c211
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521648363000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521648363000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521648363000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521648427756}]'
# b'{"time":1521648427756,"values":{"power":1251880,"power3":426150,"energyOut":34624264000,"power1":412630,"energy":11686734277000,"power2":413100}}'
# 200
# 200
# ...
# 200
# 200
# urjuh6vfpsugacs31079igtu7h
# {b'oauth_token': [b'940a3c8ba8ab41ddbf6be38e99abd501'], b'oauth_token_secret': [b'a2f7e19421954eb19e5c8ba9ae35dc73'], b'oauth_callback_confirmed': [b'true']}
# 940a3c8ba8ab41ddbf6be38e99abd501
# a2f7e19421954eb19e5c8ba9ae35dc73
# oauth_verifier=51faf00fd78c4af99e5c81091804f635
# 51faf00fd78c4af99e5c81091804f635
# hhhhh
# b'oauth_token=f60bd54fba9d414a97fe63409fdcf6f1&oauth_token_secret=7244fe022a8b4689ad6cfc68d360223a'
# f60bd54fba9d414a97fe63409fdcf6f1
# 7244fe022a8b4689ad6cfc68d360223a
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521650043000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521650043000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521650043000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521650063798}]'
# b'{"time":1521650063798,"values":{"power":745500,"power3":260410,"energyOut":34624264000,"power1":241770,"energy":11690455073000,"power2":243320}}'
# 200
# 200
# tkauqvqno97fpuco9djdphfve1
# {b'oauth_token': [b'bdac402540a7420e876b88b579621880'], b'oauth_token_secret': [b'f50e73c80bbb47a69010d12d03d8f220'], b'oauth_callback_confirmed': [b'true']}
# bdac402540a7420e876b88b579621880
# f50e73c80bbb47a69010d12d03d8f220
# oauth_verifier=3f1592d1840e4863aaaa2ba4b26ab66f
# 3f1592d1840e4863aaaa2ba4b26ab66f
# hhhhh
# b'oauth_token=9d378cff560e4e3e9e88f12358f9c285&oauth_token_secret=60c15fa890e94e729f4b5f117e0b7e91'
# 9d378cff560e4e3e9e88f12358f9c285
# 60c15fa890e94e729f4b5f117e0b7e91
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521650102000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521650103000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521650102000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521650163798}]'
# b'{"time":1521650163798,"values":{"power":757220,"power3":262080,"energyOut":34624264000,"power1":247800,"energy":11690665334000,"power2":247340}}'
# 200
# 200
# 9m15sa1ufjauknb3bvors9iiif
# {b'oauth_token': [b'c2aea2c1c6e34c15b054af134d0abdc3'], b'oauth_token_secret': [b'7f3df1e143d9431fa5e3ddc6c1822111'], b'oauth_callback_confirmed': [b'true']}
# c2aea2c1c6e34c15b054af134d0abdc3
# 7f3df1e143d9431fa5e3ddc6c1822111
# oauth_verifier=8a49b8c43bf741bd9193dbb0ad95e537
# 8a49b8c43bf741bd9193dbb0ad95e537
# hhhhh
# b'oauth_token=463a506b0fd840669188c7325df47822&oauth_token_secret=cfc6a861a17549c9a909f9dadb51e852'
# 463a506b0fd840669188c7325df47822
# cfc6a861a17549c9a909f9dadb51e852
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521650223000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521650224000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521650223000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521650265798}]'
# b'{"time":1521650265798,"values":{"power":744220,"power3":257290,"energyOut":34624264000,"power1":243760,"energy":11690878355000,"power2":243170}}'
# 200
# 200
# ie0keagji0hbk611j4ojil01kt
# {b'oauth_token': [b'5868304f0bac4ffbaa5ad69ec48dc7be'], b'oauth_token_secret': [b'f68cba8f1f79479eaac5e69167e590e4'], b'oauth_callback_confirmed': [b'true']}
# 5868304f0bac4ffbaa5ad69ec48dc7be
# f68cba8f1f79479eaac5e69167e590e4
# oauth_verifier=c674f00dfae54d578c88ffbe456ee5c7
# c674f00dfae54d578c88ffbe456ee5c7
# hhhhh
# b'oauth_token=bad7b5565a974cc0814d7496b0be6dfd&oauth_token_secret=035b9a9b1fa4479aae58d06c830caa5c'
# bad7b5565a974cc0814d7496b0be6dfd
# 035b9a9b1fa4479aae58d06c830caa5c
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521650343000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521650343000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521650343000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521650369798}]'
# b'{"time":1521650369798,"values":{"power":736690,"power3":253480,"energyOut":34624264000,"power1":241710,"energy":11691092188000,"power2":241500}}'
# 200
# 200
# hucoe75a450ko3q8h3025b1506
# {b'oauth_token': [b'dfb9270c19cd4e66b82978b4db76166b'], b'oauth_token_secret': [b'd274047062f449c99ddaf356ae071743'], b'oauth_callback_confirmed': [b'true']}
# dfb9270c19cd4e66b82978b4db76166b
# d274047062f449c99ddaf356ae071743
# oauth_verifier=0d3ec253d58643fea7f99fbb57a68f41
# 0d3ec253d58643fea7f99fbb57a68f41
# hhhhh
# b'oauth_token=48d0b3aba6124d178076ff1e918e7647&oauth_token_secret=a0e0384ba99d4073b2585ca06f9c6967'
# 48d0b3aba6124d178076ff1e918e7647
# a0e0384ba99d4073b2585ca06f9c6967
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521650403000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521650402000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521650403000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521650475799}]'
# b'{"time":1521650475799,"values":{"power":716110,"power3":247680,"energyOut":34624264000,"power1":234540,"energy":11691305697000,"power2":233890}}'
# 200
# 200
# tvopove3f2qv91nn5pmosjug3o
# {b'oauth_token': [b'1b2a3a0b6c874a368deee16a8c18326f'], b'oauth_token_secret': [b'0e952ecca26b4badbbf3f96fc29599af'], b'oauth_callback_confirmed': [b'true']}
# 1b2a3a0b6c874a368deee16a8c18326f
# 0e952ecca26b4badbbf3f96fc29599af
# oauth_verifier=2ad11db5de9e484b9c9f6e27d39384c0
# 2ad11db5de9e484b9c9f6e27d39384c0
# hhhhh
# b'oauth_token=b466710972454bbbaee7d9f4bf381b61&oauth_token_secret=3866cc4c83db485ab76741ccc1b645b1'
# b466710972454bbbaee7d9f4bf381b61
# 3866cc4c83db485ab76741ccc1b645b1
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521650523000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521650522000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521650523000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521650585799}]'
# b'{"time":1521650585799,"values":{"power":675630,"power3":234760,"energyOut":34624264000,"power1":218350,"energy":11691516986000,"power2":222520}}'
# 200
# 200
# 2gbrfamknhi5q4f0s2pal8uvo8
# {b'oauth_token': [b'4a4b7b4a9adc49519e72f25de4390818'], b'oauth_token_secret': [b'086467ec10d44476a53e5a83e75de306'], b'oauth_callback_confirmed': [b'true']}
# 4a4b7b4a9adc49519e72f25de4390818
# 086467ec10d44476a53e5a83e75de306
# oauth_verifier=56e3ee0c68514fdd96d05b1c7a60a8b4
# 56e3ee0c68514fdd96d05b1c7a60a8b4
# hhhhh
# b'oauth_token=cb0df0c68d29476fb9e0d5bbdab88694&oauth_token_secret=2e2a880a429a40bca19a4de07202f00e'
# cb0df0c68d29476fb9e0d5bbdab88694
# 2e2a880a429a40bca19a4de07202f00e
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521650643000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521650643000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521650643000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521650691799}]'
# b'{"time":1521650691799,"values":{"power":646690,"power3":224040,"energyOut":34624264000,"power1":210600,"energy":11691711575000,"power2":212050}}'
# 200

# %%
## Send Ether to the Agent Adresses so they will be able to send transactions themselves
## ONLY NEEDED WHEN THEY RUN OUT OF MONEY

#for i in (len(web3.eth.accounts)-2):
#    web3.eth.sendTransaction({'to': account_, 'from': web3.eth.coinbase, 'value': 12345})

web3.personal.unlockAccount(web3.eth.coinbase, 'hassan')

web3.eth.sendTransaction({'to': account_1, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_2, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_3, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_4, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_5, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_6, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_7, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_8, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_9, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_10, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_11, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_12, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_13, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_14, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
web3.eth.sendTransaction({'to': account_15, 'from': web3.eth.coinbase, 'value': 50000000000000000000})
# Out:
# '0xb72c59fac530ad5ec4c5ca4322eeac50185245e4d4ac524b1b6be6db5edb3af4'

# %%
len(web3.eth.accounts)
# Out:
# 24

# %%
web3.personal.newAccount()
# Out:
# Passphrase:········
# Repeat passphrase:········
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-5053c554a4e8> in <module>()
# ----> 1 web3.personal.newAccount()
#
# ~\Anaconda3\lib\site-packages\eth_utils\string.py in inner(*args, **kwargs)
#     106     @functools.wraps(fn)
#     107     def inner(*args, **kwargs):
# --> 108         return force_obj_to_text(fn(*args, **kwargs))
#     109     return inner
#
# ~\Anaconda3\lib\site-packages\web3\personal.py in newAccount(self, password)
#      52
#      53         return self.web3.manager.request_blocking(
# ---> 54             "personal_newAccount", [password],
#      55         )
#      56
#
# ~\Anaconda3\lib\site-packages\web3\manager.py in request_blocking(self, method, params)
#      94
#      95         if "error" in response:
# ---> 96             raise ValueError(response["error"])
#      97
#      98         return response['result']
#
# ValueError: {'code': -32601, 'message': 'Method not found'}

# %%
web3

# %%
web3.admin

# %%
web3.personal.newAccount('hassanharoon')
# Out:
# '0x1a6ad1ad0d9a075b8a8ba8418a08de7bd9c43481'

# %%
web3.eth.accounts
# Out:
# ['0x9702dE8eD58D66660D195dC0ee6F043Cc7f255D4',
#  '0xa1eddc56f594bc3f734c411e1A3a1444A17b6392',
#  '0x90b684b5929aA463e3d3E879a1Ee42a4358D5b7A',
#  '0x63317ab2da3fe6Ed2fbB142817eFEd027c4731fC',
#  '0x220574575F5ECc8830260411614b1f25F156198C',
#  '0x4062f4B24004262f658447F9D918CdA8897C2963',
#  '0xBC27e79d6a570Bbb0087F445141b265C047B70b4',
#  '0x9724138ce49534BEf99d6479ea38463Ba610A3DA',
#  '0x31309aE5D2f1D0BfaEFcCfd85080E3bf37cA9Ae9',
#  '0x21FF09Cc93D558747fDFe833C8FEE3c6Eb3c8734',
#  '0x41C9847454115949dd7090515338f7892b1ecf70',
#  '0x0543c15CeDc76D31C15Fb00c4F7194400ebBAD6C',
#  '0x722C511D002D9A01713e2e8EecFDc084F924738F',
#  '0x2378F746F9ac35F1a913849B3028Ff691cF803A4',
#  '0xcce2cbF7B29C2A46F477Ca5C6f902d5118741b2B',
#  '0x0B82201e51Ae74697a8E6fF0862c2CcDB44Bd8E5',
#  '0x15d7D2C90e0491b9833fEf2C1426F0C3C88eA821',
#  '0xcF19d3D27868D003cE7e2287dd1Bad7c13755fC0',
#  '0x953735291a57e96758E59Ae5b74089D11fE186A7',
#  '0x2DEBabB6768D9933DDC3d1018aD8FA3c9c12305C',
#  '0x0F35F9210A7E58F21124E9dfDE43b39E73be7942',
#  '0x3DF38b7a75B3E47281E75d2766E01AecDb4b7419',
#  '0xA6b79671eB5eADad6e0Feeb94c0790fd718f6D41',
#  '0x9B2e03D82027a7FbeA117F61D04AF8DCBBcACD4A']

# %%
account_0
# Out:
# '0x017ebC0B4A6A45Afd6560D077F19a26297778794'

# %%
def rest_power():
    url='https://api.discovergy.com'
    consumer_token_url=url+'/public/v1/oauth1/consumer_token'
    head={'Accept':'text/html, image/gif, image/jpeg, *;q=.2, */*;q=.2','Content-Type':'application/x-www-form-urlencoded'}
    data='client=OLITEST'
    ret = requests.post(consumer_token_url,data=data,headers=head)
    print(ret.status_code)
    response=ret.json()
    client_secret=response.get('secret')
    client_key=response.get('key')
    owner=response.get('owner')
    print (client_secret)

    request_token_url=url+'/public/v1/oauth1/request_token'
    oauth=OAuth1(client_key,client_secret=client_secret)
    r=requests.post(url=request_token_url, auth=oauth)
    #print (r.content)
    from urllib.parse import parse_qs
    credentials = parse_qs(r.content)
    print(credentials)
    resource_owner_key = str(credentials[b'oauth_token'][0], 'utf-8')
    resource_owner_secret= str(credentials[b'oauth_token_secret'][0],'utf-8')
    print(resource_owner_key)
    print(resource_owner_secret)

    base_authorization_url= url+'/public/v1/oauth1/authorize'
    authorize_url= base_authorization_url + '?oauth_token='
    authorize_url=authorize_url+resource_owner_key+'&email=v.hahn@mwaysolutions.com&password=mway12345'
    import urllib
    rsp=urllib.request.urlopen(authorize_url)
    rr=str(rsp.read(),'utf-8')
    print(rr)
    ident,verifier=rr.split("=")
    print(verifier)
    print('hhhhh')
    access_token_url=url+'/public/v1/oauth1/access_token'
    oauth=OAuth1(client_key,client_secret=client_secret,resource_owner_key=resource_owner_key,resource_owner_secret=resource_owner_secret,verifier=verifier)
    r=requests.post(url=access_token_url, auth=oauth)
    print(r.content)
    credentials= parse_qs(r.content)
    resource_owner_key=str(credentials[b'oauth_token'][0],'utf-8')
    resource_owner_secret=str(credentials[b'oauth_token_secret'][0],'utf-8')
    print(resource_owner_key)
    print(resource_owner_secret)
    print('aaaaaa')

    meters_url=url+'/public/v1/meters'
    oauth=OAuth1(client_key,client_secret,resource_owner_key,resource_owner_secret)
    r=requests.get(url=meters_url, auth=oauth)
    print(r.content)

    devices_url= url+'/public/v1/last_reading'
    parameter={'meterId':'EASYMETER_60671100'}
    oauth1=OAuth1(client_key,client_secret,resource_owner_key,resource_owner_secret)
    r=requests.get(url=devices_url,params=parameter,auth=oauth1)
    response= r.json()
    power=response.get('values')['power']

    print(r.content)
    print(r.status_code)
    return power

# %%
rest_power()
# Out:
# 200
# 3qlhv243u1u30co37dgonlf51d
# {b'oauth_token': [b'b9990ca29416418b96fd8a85df37f7b1'], b'oauth_token_secret': [b'9ba9f7f69d5744038776e4fa300a101a'], b'oauth_callback_confirmed': [b'true']}
# b9990ca29416418b96fd8a85df37f7b1
# 9ba9f7f69d5744038776e4fa300a101a
# oauth_verifier=2be97ae2f310476180860ff02d142aef
# 2be97ae2f310476180860ff02d142aef
# hhhhh
# b'oauth_token=40f4e3d67c0d41ce84c0807787ffcc91&oauth_token_secret=3b73d2d476724d1384a66336cf4ec25d'
# 40f4e3d67c0d41ce84c0807787ffcc91
# 3b73d2d476724d1384a66336cf4ec25d
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521644883000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521644883000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521644882000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521644901801}]'
# b'{"time":1521644901801,"values":{"power":6150150,"power3":2059770,"energyOut":34624264000,"power1":2050130,"energy":11652874892000,"power2":2040250}}'
# 200
# 6150150

# %%
truncate(rest_power(),3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-1a43131914b0> in <module>()
# ----> 1 truncate(rest_power(),3)
#
# NameError: name 'truncate' is not defined

# %%
(rest_power()
# Out:
# 200
# 1mt9m9vh6ubn3h606ao6v3jivr
# {b'oauth_token': [b'de8de0feaf6947018f6851d37d94a754'], b'oauth_token_secret': [b'19fccf46c94d4a308a4ac2fde90db474'], b'oauth_callback_confirmed': [b'true']}
# de8de0feaf6947018f6851d37d94a754
# 19fccf46c94d4a308a4ac2fde90db474
# oauth_verifier=3f662700cbd845aab685b277cb6e170c
# 3f662700cbd845aab685b277cb6e170c
# hhhhh
# b'oauth_token=bb913cfb13444510ada2d3a7ea2cdd14&oauth_token_secret=4da19e0bf07148498c942fce64761bce'
# bb913cfb13444510ada2d3a7ea2cdd14
# 4da19e0bf07148498c942fce64761bce
# aaaaaa
# b'[{"serialNumber":"07290498","location":{"street":"Siemensstr.","streetNumber":"9","zip":"93055","city":"Regensburg","country":"DE"},"administrationNumber":"DE0005319305500801776820000000000","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519904071000,"lastMeasurementTime":1521644642000},{"serialNumber":"07290496","location":{"street":"Industriestr.","streetNumber":"3","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003665737","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":50,"currentScalingFactor":50,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680284000,"lastMeasurementTime":1521644644000},{"serialNumber":"07290497","location":{"street":"Industriestr.","streetNumber":"1","zip":"92331","city":"Parsberg","country":"DE"},"administrationNumber":"DE0010689233110000000000003748511","type":"RLM","measurementType":"ELECTRICITY","scalingFactor":100,"currentScalingFactor":100,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1518680448000,"lastMeasurementTime":1521644643000},{"serialNumber":"60671100","location":{"street":"B\xc3\xbcrgerreuther Str.","streetNumber":"16","zip":"95444","city":"Bayreuth","country":"DE"},"administrationNumber":"DE0000749544420010960016203606016","type":"EASYMETER","measurementType":"ELECTRICITY","scalingFactor":1,"currentScalingFactor":1,"voltageScalingFactor":1,"internalMeters":1,"firstMeasurementTime":1519828601091,"lastMeasurementTime":1521644689907}]'
# b'{"time":1521644689907,"values":{"power":6532320,"power3":2182840,"energyOut":34624264000,"power1":2175730,"energy":11649142042000,"power2":2173750}}'
# 200
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-585888d5d75d> in <module>()
# ----> 1 rest_power().truncate()
#
# AttributeError: 'int' object has no attribute 'truncate'

# %%
web3.personal.unlockAccount(coinbase, 'hassan')

web3.eth.sendTransaction({'to': '0x9758c22e45ee5b8c1ee948734e8a1195557f023a', 'from': web3.eth.coinbase, 'value': 50000000000000000000})

web3.eth.sendTransaction({'to': '0x15c41571221c47f0670e2b66d4a32958586ef705', 'from': web3.eth.coinbase, 'value': 50000000000000000000})
# Out:
# '0x77f57b7ecd5dff91b02a121251eeffab8cc6e05dc4cb3ad38abc3d6e2dded689'
